# %%
import numpy as np
arr1 = np.array([10, 20, 30, 40])
print("1D Array:", arr1)

arr2 = np.array([[1, 2, 3],
                 [4, 5, 6]])
print("2D Array:")
print(arr2)
# Out:
# 1D Array: [10 20 30 40]
# 2D Array:
# [[1 2 3]
#  [4 5 6]]
