# %%
sentence = "Data science uses Python a lot"

words = sentence.split()

print("Words list:", words)

joined_sentence = "-".join(words)

print("Joined sentence:", joined_sentence)
# Out:
# Words list: ['Data', 'science', 'uses', 'Python', 'a', 'lot']
# Joined sentence: Data-science-uses-Python-a-lot
