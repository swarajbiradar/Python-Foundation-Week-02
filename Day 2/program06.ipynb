# %%
paragraph = "Python is one of the most popular programming languages in the world."

print("Uppercase:", paragraph.upper())

print("Replaced:", paragraph.replace("popular", "powerful"))

print("Length of paragraph:", len(paragraph))

words = paragraph.split()
print("Words:", words)
# Out:
# Uppercase: PYTHON IS ONE OF THE MOST POPULAR PROGRAMMING LANGUAGES IN THE WORLD.
# Replaced: Python is one of the most powerful programming languages in the world.
# Length of paragraph: 69
# Words: ['Python', 'is', 'one', 'of', 'the', 'most', 'popular', 'programming', 'languages', 'in', 'the', 'world.']
