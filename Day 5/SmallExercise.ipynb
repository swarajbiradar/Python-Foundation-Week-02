# %%
import numpy as np
data = np.random.randint(50,100,10)

print("Random Dataset:", data)

print("Sum:", np.sum(data))
print("Mean:", np.mean(data))
print("Max:", np.max(data))
print("Min:", np.min(data))
print("Standard Deviation:", np.std(data))
# Out:
# Random Dataset: [86 84 73 86 75 74 97 99 85 66]
# Sum: 825
# Mean: 82.5
# Max: 99
# Min: 66
# Standard Deviation: 10.032447358446493
