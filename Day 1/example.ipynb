# %%
students = {
    "John": {"age": 20, "grade": "A"},
    "Emma": {"age": 21, "grade": "B"},
    "Mike": {"age": 19, "grade": "A"}
}

print("Student Data:", students)

print("Emma's Grade:", students["Emma"]["grade"])
# Out:
# Student Data: {'John': {'age': 20, 'grade': 'A'}, 'Emma': {'age': 21, 'grade': 'B'}, 'Mike': {'age': 19, 'grade': 'A'}}
# Emma's Grade: B
