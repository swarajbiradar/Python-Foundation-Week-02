# %%
numbers = (10, 20, 30, 20)

print("Tuple:", numbers)

# Access elements
print("First element:", numbers[0])
print("Second element:", numbers[1])
# Out:
# Tuple: (10, 20, 30, 20)
# First element: 10
# Second element: 20
