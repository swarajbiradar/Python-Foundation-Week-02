# %%
fruit_set = {"apple", "banana", "mango", "apple"}

print("Set (duplicates removed):", fruit_set)

fruit_set.add("orange")
print("After adding orange:", fruit_set)
# Out:
# Set (duplicates removed): {'apple', 'mango', 'banana'}
# After adding orange: {'apple', 'orange', 'mango', 'banana'}
