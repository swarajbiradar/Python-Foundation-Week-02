# %%
student_grades = {
    "Alice": 85,
    "Bob": 90,
    "Charlie": 78
}

print("Student grades:", student_grades)


print("Alice's grade:", student_grades["Alice"])

student_grades["David"] = 92
print("Updated dictionary:", student_grades)
# Out:
# Student grades: {'Alice': 85, 'Bob': 90, 'Charlie': 78}
# Alice's grade: 85
# Updated dictionary: {'Alice': 85, 'Bob': 90, 'Charlie': 78, 'David': 92}
