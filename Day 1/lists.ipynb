# %%
fruits = ["apple", "banana", "mango", "apple"]

print("List:", fruits)

fruits.append("orange")
print("After adding fruit:", fruits)

fruits[1] = "grapes"
print("After modifying:", fruits)
# Out:
# List: ['apple', 'banana', 'mango', 'apple']
# After adding fruit: ['apple', 'banana', 'mango', 'apple', 'orange']
# After modifying: ['apple', 'grapes', 'mango', 'apple', 'orange']
